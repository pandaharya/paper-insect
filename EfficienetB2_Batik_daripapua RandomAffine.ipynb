# %% [markdown]
# <a href="https://colab.research.google.com/github/pandaharya/paper-insect/blob/main/EfficienetB2_Batik_daripapua%20RandomAffine.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install geffnet
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting geffnet
#   Downloading geffnet-1.0.2-py3-none-any.whl (40 kB)
#      |████████████████████████████████| 40 kB 5.5 MB/s
# Requirement already satisfied: torchvision in /usr/local/lib/python3.7/dist-packages (from geffnet) (0.13.0+cu113)
# Requirement already satisfied: torch>=1.4 in /usr/local/lib/python3.7/dist-packages (from geffnet) (1.12.0+cu113)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.7/dist-packages (from torch>=1.4->geffnet) (4.1.1)
# Requirement already satisfied: pillow!=8.3.*,>=5.3.0 in /usr/local/lib/python3.7/dist-packages (from torchvision->geffnet) (7.1.2)
# Requirement already satisfied: numpy in /usr/local/lib/python3.7/dist-packages (from torchvision->geffnet) (1.21.6)
# Requirement already satisfied: requests in /usr/local/lib/python3.7/dist-packages (from torchvision->geffnet) (2.23.0)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests->torchvision->geffnet) (3.0.4)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests->torchvision->geffnet) (2.10)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests->torchvision->geffnet) (2022.6.15)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests->torchvision->geffnet) (1.24.3)
# Installing collected packages: geffnet
# Successfully installed geffnet-1.0.2

# %% [markdown]
# ### **Import Necessary Libraries:**

# %%
import numpy as np
import pandas as pd
import glob
import math
import os
import torch
import random
from torchvision import datasets, transforms, models
from torch import nn, optim
import torch.nn.functional as F
from torch.optim.lr_scheduler import StepLR
import matplotlib.pyplot as plt
from PIL import Image
from pathlib import Path
# %matplotlib inline
# %config InlineBackend.figure_format = 'retina'
 
import geffnet

# %%
# !nvidia-smi
# Out:
# Mon Aug  1 04:40:36 2022
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 460.32.03    Driver Version: 460.32.03    CUDA Version: 11.2     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  Tesla P100-PCIE...  Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   38C    P0    28W / 250W |      2MiB / 16280MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
#
# +-----------------------------------------------------------------------------+
# | Processes:                                                                  |
# |  GPU   GI   CI        PID   Type   Process name                  GPU Memory |
# |        ID   ID                                                   Usage      |
# |=============================================================================|
# |  No running processes found                                                 |
# +-----------------------------------------------------------------------------+

# %%
# For mounting Google drive, as I was using Google Collab and my Dataset was in Google drive
from google.colab import drive
drive.mount('/content/gdrive')
# %cd /content/gdrive/MyDrive
# Out:
# Mounted at /content/gdrive
# /content/gdrive/MyDrive

# %%
# Get the total number of images in each class
file_count = 0
classes = os.listdir("/content/gdrive/MyDrive/motifbatikpapua3/val")
for cat in ['train', 'val', 'test']:
  files = glob.glob('/content/gdrive/MyDrive/motifbatikpapua3/'+cat+'/*/*')
  print(cat,'Images:',len(files), end = ', ')
print('\n')
for direc in classes:
  files = glob.glob('/content/gdrive/MyDrive/motifbatikpapua3/*/'+direc+'/*')
  file_count += len(files)
  print(direc, len(files))
print(file_count)
# Out:
# train Images: 177, val Images: 23, test Images: 24,
#
# motif asmat 67
# motif cendrawasih 51
# motif raja ampat 53
# motif tifa honai 53
# 224

# %% [markdown]
# ## **Load The Data**

# %%
from torchvision.transforms.transforms import RandomCrop
data_dir = '/content/gdrive/MyDrive/motifbatikpapua3'
random.seed(41)

#Data Tranforms (Augmentation and Normalization)
train_transforms = transforms.Compose([
                                       #transforms.RandomResizedCrop(size=256, scale=(0.8, 1.0)),
                                       #transforms.RandomRotation(45),
                                       #transforms.ColorJitter(brightness=.4, contrast=.4, saturation=.4, hue=.4),
                                       transforms.RandomAffine(degrees=(30, 70), translate=(0.1, 0.3), scale=(0.5, 0.75)),
                                       #transforms.RandomInvert(),
                                       #transforms.RandomGrayscale(),
                                       #transforms.RandomHorizontalFlip(),
                                       #transforms.RandomVerticalFlip(),
                                       transforms.Resize(size=(224,224)),
                                       transforms.ToTensor(),
                                       transforms.Normalize([0.485, 0.456, 0.406],
                             [0.229, 0.224, 0.225])])
val_transforms = transforms.Compose([
                                       #transforms.RandomRotation(45),
                                       #transforms.RandomHorizontalFlip(0.6),
                                       transforms.Resize(size=(224,224)),
                                       transforms.ToTensor(),
                                       transforms.Normalize([0.485, 0.456, 0.406],
                             [0.229, 0.224, 0.225])])
test_transforms = transforms.Compose([transforms.Resize(size=(224,224)),
                                       transforms.ToTensor(),
                                       transforms.Normalize([0.485, 0.456, 0.406],
                             [0.229, 0.224, 0.225])])

#Getting all the data with PyTorch Datasets
train_data = datasets.ImageFolder(data_dir + '/train', transform= train_transforms)
val_data = datasets.ImageFolder(data_dir + '/val', transform= val_transforms)
test_data = datasets.ImageFolder(data_dir + '/test', transform= test_transforms)

#Loading the data into PyTorch DataLoader
train_loader = torch.utils.data.DataLoader(train_data, batch_size= 64, shuffle = True,num_workers=2)
valid_loader = torch.utils.data.DataLoader(val_data, batch_size= 64, shuffle = True,num_workers=2)
test_loader = torch.utils.data.DataLoader(test_data, batch_size= 64, shuffle = True,num_workers=2)

#Creating a dictionary of all classes
classes = dict(zip(list(range(len(train_data.classes))),train_data.classes))

# %% [markdown]
# ### **Check the images with labels**

# %%
def denormalise(image):
  try:
    image = image.cpu().numpy().transpose(1, 2, 0)
  except:
    image = image.transpose(1, 2, 0) # PIL images have channel last
  mean = [0.485, 0.456, 0.406]
  stdd = [0.229, 0.224, 0.225]
  image = (image * stdd + mean).clip(0, 1)
  return image

dataiter = iter(train_loader)
images, labels = dataiter.next()
images = images.numpy()
fig = plt.figure(figsize=(15,15))

for idx in np.arange(25):
  ax = fig.add_subplot(5, 5, idx+1, xticks=[], yticks=[])
  ax.imshow(denormalise(images[idx]), cmap='gray')
  ax.set_title(classes[labels[idx].item()])

# %% [markdown]
# ## **Load the model**

# %%
# Specify the device type
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
device
# Out:
# device(type='cuda')

# %%
# Loading the model
model = geffnet.create_model('efficientnet_b2', pretrained=True)

#Freezing all the layers
for param in model.parameters():
  param.requires_grad = False 

# Changing the Classifier
model.classifier = nn.Sequential(nn.Linear(1408,512),
                           nn.ReLU(),
                           nn.Dropout(p=0.4),
                           nn.Linear(512,128),
                           nn.ReLU(),
                           nn.Dropout(p=0.4),
                           nn.Linear(128,len(classes)))

# Making the Classifier layer Trainable                           
for param in model.classifier.parameters():
  param.requires_grad = True

# Moving the model to device
model.to(device)
# Out:
# Downloading: "https://github.com/rwightman/pytorch-image-models/releases/download/v0.1-weights/efficientnet_b2_ra-bcdf34b7.pth" to /root/.cache/torch/hub/checkpoints/efficientnet_b2_ra-bcdf34b7.pth
# GenEfficientNet(
#   (conv_stem): Conv2d(3, 32, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#   (bn1): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (act1): SiLU(inplace=True)
#   (blocks): Sequential(
#     (0): Sequential(
#       (0): DepthwiseSeparableConv(
#         (conv_dw): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=32, bias=False)
#         (bn1): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (act1): SiLU(inplace=True)
#         (se): SqueezeExcite(
#           (conv_reduce): Conv2d(32, 8, kernel_size=(1, 1), stride=(1, 1))
#           (act1): SiLU(inplace=True)
#           (conv_expand): Conv2d(8, 32, kernel_size=(1, 1), stride=(1, 1))
#         )
#         (conv_pw): Conv2d(32, 16, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn2): BatchNorm2d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (act2): Identity()
#       )
#       (1): DepthwiseSeparableConv(
#         (conv_dw): Conv2d(16, 16, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=16, bias=False)
#         (bn1): BatchNorm2d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (act1): SiLU(inplace=True)
#         (se): SqueezeExcite(
#           (conv_reduce): Conv2d(16, 4, kernel_size=(1, 1), stride=(1, 1))
#           (act1): SiLU(inplace=True)
#           (conv_expand): Conv2d(4, 16, kernel_size=(1, 1), stride=(1, 1))
#         )
#         (conv_pw): Conv2d(16, 16, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn2): BatchNorm2d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (act2): Identity()
#       )
#     )
#     (1): Sequential(
#       (0): InvertedResidual(
#         (conv_pw): Conv2d(16, 96, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNorm2d(96, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (act1): SiLU(inplace=True)
#         (conv_dw): Conv2d(96, 96, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), groups=96, bias=False)
#         (bn2): BatchNorm2d(96, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (act2): SiLU(inplace=True)
#         (se): SqueezeExcite(
#           (conv_reduce): Conv2d(96, 4, kernel_size=(1, 1), stride=(1, 1))
#           (act1): SiLU(inplace=True)
#           (conv_expand): Conv2d(4, 96, kernel_size=(1, 1), stride=(1, 1))
#         )
#         (conv_pwl): Conv2d(96, 24, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNorm2d(24, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (1): InvertedResidual(
#         (conv_pw): Conv2d(24, 144, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNorm2d(144, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (act1): SiLU(inplace=True)
#         (conv_dw): Conv2d(144, 144, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=144, bias=False)
#         (bn2): BatchNorm2d(144, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (act2): SiLU(inplace=True)
#         (se): SqueezeExcite(
#           (conv_reduce): Conv2d(144, 6, kernel_size=(1, 1), stride=(1, 1))
#           (act1): SiLU(inplace=True)
#           (conv_expand): Conv2d(6, 144, kernel_size=(1, 1), stride=(1, 1))
#         )
#         (conv_pwl): Conv2d(144, 24, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNorm2d(24, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (2): InvertedResidual(
#         (conv_pw): Conv2d(24, 144, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNorm2d(144, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (act1): SiLU(inplace=True)
#         (conv_dw): Conv2d(144, 144, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=144, bias=False)
#         (bn2): BatchNorm2d(144, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (act2): SiLU(inplace=True)
#         (se): SqueezeExcite(
#           (conv_reduce): Conv2d(144, 6, kernel_size=(1, 1), stride=(1, 1))
#           (act1): SiLU(inplace=True)
#           (conv_expand): Conv2d(6, 144, kernel_size=(1, 1), stride=(1, 1))
#         )
#         (conv_pwl): Conv2d(144, 24, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNorm2d(24, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (2): Sequential(
#       (0): InvertedResidual(
#         (conv_pw): Conv2d(24, 144, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNorm2d(144, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (act1): SiLU(inplace=True)
#         (conv_dw): Conv2d(144, 144, kernel_size=(5, 5), stride=(2, 2), padding=(2, 2), groups=144, bias=False)
#         (bn2): BatchNorm2d(144, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (act2): SiLU(inplace=True)
#         (se): SqueezeExcite(
#           (conv_reduce): Conv2d(144, 6, kernel_size=(1, 1), stride=(1, 1))
#           (act1): SiLU(inplace=True)
#           (conv_expand): Conv2d(6, 144, kernel_size=(1, 1), stride=(1, 1))
#         )
#         (conv_pwl): Conv2d(144, 48, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNorm2d(48, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (1): InvertedResidual(
#         (conv_pw): Conv2d(48, 288, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNorm2d(288, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (act1): SiLU(inplace=True)
#         (conv_dw): Conv2d(288, 288, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2), groups=288, bias=False)
#         (bn2): BatchNorm2d(288, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (act2): SiLU(inplace=True)
#         (se): SqueezeExcite(
#           (conv_reduce): Conv2d(288, 12, kernel_size=(1, 1), stride=(1, 1))
#           (act1): SiLU(inplace=True)
#           (conv_expand): Conv2d(12, 288, kernel_size=(1, 1), stride=(1, 1))
#         )
#         (conv_pwl): Conv2d(288, 48, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNorm2d(48, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (2): InvertedResidual(
#         (conv_pw): Conv2d(48, 288, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNorm2d(288, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (act1): SiLU(inplace=True)
#         (conv_dw): Conv2d(288, 288, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2), groups=288, bias=False)
#         (bn2): BatchNorm2d(288, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (act2): SiLU(inplace=True)
#         (se): SqueezeExcite(
#           (conv_reduce): Conv2d(288, 12, kernel_size=(1, 1), stride=(1, 1))
#           (act1): SiLU(inplace=True)
#           (conv_expand): Conv2d(12, 288, kernel_size=(1, 1), stride=(1, 1))
#         )
#         (conv_pwl): Conv2d(288, 48, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNorm2d(48, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (3): Sequential(
#       (0): InvertedResidual(
#         (conv_pw): Conv2d(48, 288, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNorm2d(288, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (act1): SiLU(inplace=True)
#         (conv_dw): Conv2d(288, 288, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), groups=288, bias=False)
#         (bn2): BatchNorm2d(288, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (act2): SiLU(inplace=True)
#         (se): SqueezeExcite(
#           (conv_reduce): Conv2d(288, 12, kernel_size=(1, 1), stride=(1, 1))
#           (act1): SiLU(inplace=True)
#           (conv_expand): Conv2d(12, 288, kernel_size=(1, 1), stride=(1, 1))
#         )
#         (conv_pwl): Conv2d(288, 88, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNorm2d(88, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (1): InvertedResidual(
#         (conv_pw): Conv2d(88, 528, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNorm2d(528, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (act1): SiLU(inplace=True)
#         (conv_dw): Conv2d(528, 528, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=528, bias=False)
#         (bn2): BatchNorm2d(528, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (act2): SiLU(inplace=True)
#         (se): SqueezeExcite(
#           (conv_reduce): Conv2d(528, 22, kernel_size=(1, 1), stride=(1, 1))
#           (act1): SiLU(inplace=True)
#           (conv_expand): Conv2d(22, 528, kernel_size=(1, 1), stride=(1, 1))
#         )
#         (conv_pwl): Conv2d(528, 88, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNorm2d(88, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (2): InvertedResidual(
#         (conv_pw): Conv2d(88, 528, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNorm2d(528, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (act1): SiLU(inplace=True)
#         (conv_dw): Conv2d(528, 528, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=528, bias=False)
#         (bn2): BatchNorm2d(528, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (act2): SiLU(inplace=True)
#         (se): SqueezeExcite(
#           (conv_reduce): Conv2d(528, 22, kernel_size=(1, 1), stride=(1, 1))
#           (act1): SiLU(inplace=True)
#           (conv_expand): Conv2d(22, 528, kernel_size=(1, 1), stride=(1, 1))
#         )
#         (conv_pwl): Conv2d(528, 88, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNorm2d(88, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (3): InvertedResidual(
#         (conv_pw): Conv2d(88, 528, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNorm2d(528, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (act1): SiLU(inplace=True)
#         (conv_dw): Conv2d(528, 528, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=528, bias=False)
#         (bn2): BatchNorm2d(528, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (act2): SiLU(inplace=True)
#         (se): SqueezeExcite(
#           (conv_reduce): Conv2d(528, 22, kernel_size=(1, 1), stride=(1, 1))
#           (act1): SiLU(inplace=True)
#           (conv_expand): Conv2d(22, 528, kernel_size=(1, 1), stride=(1, 1))
#         )
#         (conv_pwl): Conv2d(528, 88, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNorm2d(88, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (4): Sequential(
#       (0): InvertedResidual(
#         (conv_pw): Conv2d(88, 528, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNorm2d(528, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (act1): SiLU(inplace=True)
#         (conv_dw): Conv2d(528, 528, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2), groups=528, bias=False)
#         (bn2): BatchNorm2d(528, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (act2): SiLU(inplace=True)
#         (se): SqueezeExcite(
#           (conv_reduce): Conv2d(528, 22, kernel_size=(1, 1), stride=(1, 1))
#           (act1): SiLU(inplace=True)
#           (conv_expand): Conv2d(22, 528, kernel_size=(1, 1), stride=(1, 1))
#         )
#         (conv_pwl): Conv2d(528, 120, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNorm2d(120, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (1): InvertedResidual(
#         (conv_pw): Conv2d(120, 720, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNorm2d(720, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (act1): SiLU(inplace=True)
#         (conv_dw): Conv2d(720, 720, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2), groups=720, bias=False)
#         (bn2): BatchNorm2d(720, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (act2): SiLU(inplace=True)
#         (se): SqueezeExcite(
#           (conv_reduce): Conv2d(720, 30, kernel_size=(1, 1), stride=(1, 1))
#           (act1): SiLU(inplace=True)
#           (conv_expand): Conv2d(30, 720, kernel_size=(1, 1), stride=(1, 1))
#         )
#         (conv_pwl): Conv2d(720, 120, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNorm2d(120, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (2): InvertedResidual(
#         (conv_pw): Conv2d(120, 720, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNorm2d(720, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (act1): SiLU(inplace=True)
#         (conv_dw): Conv2d(720, 720, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2), groups=720, bias=False)
#         (bn2): BatchNorm2d(720, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (act2): SiLU(inplace=True)
#         (se): SqueezeExcite(
#           (conv_reduce): Conv2d(720, 30, kernel_size=(1, 1), stride=(1, 1))
#           (act1): SiLU(inplace=True)
#           (conv_expand): Conv2d(30, 720, kernel_size=(1, 1), stride=(1, 1))
#         )
#         (conv_pwl): Conv2d(720, 120, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNorm2d(120, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (3): InvertedResidual(
#         (conv_pw): Conv2d(120, 720, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNorm2d(720, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (act1): SiLU(inplace=True)
#         (conv_dw): Conv2d(720, 720, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2), groups=720, bias=False)
#         (bn2): BatchNorm2d(720, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (act2): SiLU(inplace=True)
#         (se): SqueezeExcite(
#           (conv_reduce): Conv2d(720, 30, kernel_size=(1, 1), stride=(1, 1))
#           (act1): SiLU(inplace=True)
#           (conv_expand): Conv2d(30, 720, kernel_size=(1, 1), stride=(1, 1))
#         )
#         (conv_pwl): Conv2d(720, 120, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNorm2d(120, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (5): Sequential(
#       (0): InvertedResidual(
#         (conv_pw): Conv2d(120, 720, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNorm2d(720, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (act1): SiLU(inplace=True)
#         (conv_dw): Conv2d(720, 720, kernel_size=(5, 5), stride=(2, 2), padding=(2, 2), groups=720, bias=False)
#         (bn2): BatchNorm2d(720, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (act2): SiLU(inplace=True)
#         (se): SqueezeExcite(
#           (conv_reduce): Conv2d(720, 30, kernel_size=(1, 1), stride=(1, 1))
#           (act1): SiLU(inplace=True)
#           (conv_expand): Conv2d(30, 720, kernel_size=(1, 1), stride=(1, 1))
#         )
#         (conv_pwl): Conv2d(720, 208, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNorm2d(208, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (1): InvertedResidual(
#         (conv_pw): Conv2d(208, 1248, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNorm2d(1248, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (act1): SiLU(inplace=True)
#         (conv_dw): Conv2d(1248, 1248, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2), groups=1248, bias=False)
#         (bn2): BatchNorm2d(1248, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (act2): SiLU(inplace=True)
#         (se): SqueezeExcite(
#           (conv_reduce): Conv2d(1248, 52, kernel_size=(1, 1), stride=(1, 1))
#           (act1): SiLU(inplace=True)
#           (conv_expand): Conv2d(52, 1248, kernel_size=(1, 1), stride=(1, 1))
#         )
#         (conv_pwl): Conv2d(1248, 208, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNorm2d(208, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (2): InvertedResidual(
#         (conv_pw): Conv2d(208, 1248, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNorm2d(1248, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (act1): SiLU(inplace=True)
#         (conv_dw): Conv2d(1248, 1248, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2), groups=1248, bias=False)
#         (bn2): BatchNorm2d(1248, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (act2): SiLU(inplace=True)
#         (se): SqueezeExcite(
#           (conv_reduce): Conv2d(1248, 52, kernel_size=(1, 1), stride=(1, 1))
#           (act1): SiLU(inplace=True)
#           (conv_expand): Conv2d(52, 1248, kernel_size=(1, 1), stride=(1, 1))
#         )
#         (conv_pwl): Conv2d(1248, 208, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNorm2d(208, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (3): InvertedResidual(
#         (conv_pw): Conv2d(208, 1248, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNorm2d(1248, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (act1): SiLU(inplace=True)
#         (conv_dw): Conv2d(1248, 1248, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2), groups=1248, bias=False)
#         (bn2): BatchNorm2d(1248, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (act2): SiLU(inplace=True)
#         (se): SqueezeExcite(
#           (conv_reduce): Conv2d(1248, 52, kernel_size=(1, 1), stride=(1, 1))
#           (act1): SiLU(inplace=True)
#           (conv_expand): Conv2d(52, 1248, kernel_size=(1, 1), stride=(1, 1))
#         )
#         (conv_pwl): Conv2d(1248, 208, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNorm2d(208, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (4): InvertedResidual(
#         (conv_pw): Conv2d(208, 1248, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNorm2d(1248, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (act1): SiLU(inplace=True)
#         (conv_dw): Conv2d(1248, 1248, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2), groups=1248, bias=False)
#         (bn2): BatchNorm2d(1248, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (act2): SiLU(inplace=True)
#         (se): SqueezeExcite(
#           (conv_reduce): Conv2d(1248, 52, kernel_size=(1, 1), stride=(1, 1))
#           (act1): SiLU(inplace=True)
#           (conv_expand): Conv2d(52, 1248, kernel_size=(1, 1), stride=(1, 1))
#         )
#         (conv_pwl): Conv2d(1248, 208, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNorm2d(208, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (6): Sequential(
#       (0): InvertedResidual(
#         (conv_pw): Conv2d(208, 1248, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNorm2d(1248, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (act1): SiLU(inplace=True)
#         (conv_dw): Conv2d(1248, 1248, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=1248, bias=False)
#         (bn2): BatchNorm2d(1248, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (act2): SiLU(inplace=True)
#         (se): SqueezeExcite(
#           (conv_reduce): Conv2d(1248, 52, kernel_size=(1, 1), stride=(1, 1))
#           (act1): SiLU(inplace=True)
#           (conv_expand): Conv2d(52, 1248, kernel_size=(1, 1), stride=(1, 1))
#         )
#         (conv_pwl): Conv2d(1248, 352, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNorm2d(352, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (1): InvertedResidual(
#         (conv_pw): Conv2d(352, 2112, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNorm2d(2112, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (act1): SiLU(inplace=True)
#         (conv_dw): Conv2d(2112, 2112, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=2112, bias=False)
#         (bn2): BatchNorm2d(2112, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (act2): SiLU(inplace=True)
#         (se): SqueezeExcite(
#           (conv_reduce): Conv2d(2112, 88, kernel_size=(1, 1), stride=(1, 1))
#           (act1): SiLU(inplace=True)
#           (conv_expand): Conv2d(88, 2112, kernel_size=(1, 1), stride=(1, 1))
#         )
#         (conv_pwl): Conv2d(2112, 352, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNorm2d(352, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#   )
#   (conv_head): Conv2d(352, 1408, kernel_size=(1, 1), stride=(1, 1), bias=False)
#   (bn2): BatchNorm2d(1408, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (act2): SiLU(inplace=True)
#   (global_pool): AdaptiveAvgPool2d(output_size=1)
#   (classifier): Sequential(
#     (0): Linear(in_features=1408, out_features=512, bias=True)
#     (1): ReLU()
#     (2): Dropout(p=0.4, inplace=False)
#     (3): Linear(in_features=512, out_features=128, bias=True)
#     (4): ReLU()
#     (5): Dropout(p=0.4, inplace=False)
#     (6): Linear(in_features=128, out_features=4, bias=True)
#   )
# )

# %% [markdown]
# ### **Specify the Loss Criterion, Optimizer and Scheduler**

# %%
criterion = nn.CrossEntropyLoss()
optimizer  = optim.Adam(model.classifier.parameters(),lr = 0.01)
scheduler = StepLR(optimizer, step_size=6, gamma=0.35)

# %% [markdown]
# ## **Train The Model**

# %%
epochs = 100 # Number of epochs
steps = 0
print_every = 5 
train_losses, valid_losses,valid_acc = [], [], [] # List keeping track of losses and accuracy to plot later
valid_loss_min = np.Inf # It will be used to save model whenever Vallidation loss decreases
valid_acc_min = 0.0 

for e in range(epochs):
  
  train_loss = 0 
  model.train()
  #train the model
  for images, labels in train_loader:
    steps+=1
    # Move tensor to device('cuda' in case of GPU or 'cpu' in case of CPU)
    images, labels = images.to(device), labels.to(device)
    # Clearing all the previous gradients
    optimizer.zero_grad()
    # Forward Pass
    logits = model(images)
    # Loss calculation
    loss = criterion(logits,labels)
    # Backward Pass
    loss.backward()
    # Update the parameters
    optimizer.step()
    # Updating the losses list
    train_loss += loss.item()

    # Evaluating after specific amount of steps
    if steps % print_every == 0:
      valid_loss = 0
      accuracy = 0
      # Setting Model to Evaluation Mode
      model.eval()
      with torch.no_grad():
        # Getting Validation loss
        for images, labels in valid_loader:
          images, labels = images.to(device), labels.to(device)
          logits = model(images)
          batch_loss = criterion(logits,labels)
          valid_loss += batch_loss.item()
          
          # Calculating Accuracy
          output = F.softmax(logits,dim=1)
          top_p,top_class = output.topk(1,dim = 1)
          equals = top_class == labels.view(*top_class.shape)
          accuracy += torch.mean(equals.type(torch.FloatTensor)).item()
      # Printing stats    
      print(f"Epoch {e+1}/{epochs}.. "
                  f"Train loss: {train_loss/print_every:.3f}.. "
                  f"Validation loss: {valid_loss/len(valid_loader):.3f}.. "
                  f"Validation accuracy: {accuracy/len(valid_loader):.3f}.. "
                  f"LR : {scheduler.get_lr():}"
                  )
      valid_loss = valid_loss/len(valid_loader)
      train_losses.append(train_loss/print_every)
      valid_losses.append(valid_loss)
      valid_acc.append(accuracy/len(valid_loader))
      
      # Checking if Validation loss decreased
      if valid_loss <= valid_loss_min:
        
        # if decreased, it will save the model
        print('valid loss decreased ({:.6f} --> {:.6f}).  Saving model ...'.format(
        valid_loss_min,
        valid_loss))
        torch.save(model.state_dict(), 'model.pt')
        valid_loss_min = valid_loss
      
      
  # Scheduler performing a step to change learning rate of Optimizer    
  scheduler.step()
# Out:
# /usr/local/lib/python3.7/dist-packages/torch/optim/lr_scheduler.py:372: UserWarning: To get the last learning rate computed by the scheduler, please use `get_last_lr()`.
#   "please use `get_last_lr()`.", UserWarning)
# Epoch 2/100.. Train loss: 0.433.. Validation loss: 1.095.. Validation accuracy: 0.682.. LR : [0.01]
# valid loss decreased (inf --> 1.095464).  Saving model ...
# Epoch 4/100.. Train loss: 0.136.. Validation loss: 1.631.. Validation accuracy: 0.364.. LR : [0.01]
# Epoch 5/100.. Train loss: 0.515.. Validation loss: 1.015.. Validation accuracy: 0.636.. LR : [0.01]
# valid loss decreased (1.095464 --> 1.014801).  Saving model ...
# Epoch 7/100.. Train loss: 0.222.. Validation loss: 1.176.. Validation accuracy: 0.591.. LR : [0.0012249999999999997]
# Epoch 9/100.. Train loss: 0.083.. Validation loss: 1.174.. Validation accuracy: 0.500.. LR : [0.0034999999999999996]
# Epoch 10/100.. Train loss: 0.238.. Validation loss: 1.120.. Validation accuracy: 0.591.. LR : [0.0034999999999999996]
# Epoch 12/100.. Train loss: 0.106.. Validation loss: 1.164.. Validation accuracy: 0.500.. LR : [0.0034999999999999996]
# Epoch 14/100.. Train loss: 0.041.. Validation loss: 1.135.. Validation accuracy: 0.591.. LR : [0.0012249999999999997]
# Epoch 15/100.. Train loss: 0.154.. Validation loss: 1.162.. Validation accuracy: 0.591.. LR : [0.0012249999999999997]
# Epoch 17/100.. Train loss: 0.073.. Validation loss: 1.202.. Validation accuracy: 0.545.. LR : [0.0012249999999999997]
# Epoch 19/100.. Train loss: 0.025.. Validation loss: 1.222.. Validation accuracy: 0.545.. LR : [0.00015006249999999994]
# Epoch 20/100.. Train loss: 0.111.. Validation loss: 1.229.. Validation accuracy: 0.545.. LR : [0.0004287499999999999]
# Epoch 22/100.. Train loss: 0.048.. Validation loss: 1.223.. Validation accuracy: 0.545.. LR : [0.0004287499999999999]
# Epoch 24/100.. Train loss: 0.050.. Validation loss: 1.182.. Validation accuracy: 0.500.. LR : [0.0004287499999999999]
# Epoch 25/100.. Train loss: 0.116.. Validation loss: 1.183.. Validation accuracy: 0.500.. LR : [5.2521874999999974e-05]
# Epoch 27/100.. Train loss: 0.051.. Validation loss: 1.230.. Validation accuracy: 0.455.. LR : [0.00015006249999999994]
# Epoch 29/100.. Train loss: 0.024.. Validation loss: 1.197.. Validation accuracy: 0.455.. LR : [0.00015006249999999994]
# Epoch 30/100.. Train loss: 0.083.. Validation loss: 1.193.. Validation accuracy: 0.500.. LR : [0.00015006249999999994]
# Epoch 32/100.. Train loss: 0.070.. Validation loss: 1.159.. Validation accuracy: 0.500.. LR : [5.2521874999999974e-05]
# Epoch 34/100.. Train loss: 0.043.. Validation loss: 1.150.. Validation accuracy: 0.545.. LR : [5.2521874999999974e-05]
# Epoch 35/100.. Train loss: 0.097.. Validation loss: 1.178.. Validation accuracy: 0.455.. LR : [5.2521874999999974e-05]
# Epoch 37/100.. Train loss: 0.030.. Validation loss: 1.152.. Validation accuracy: 0.500.. LR : [6.433929687499997e-06]
# Epoch 39/100.. Train loss: 0.035.. Validation loss: 1.160.. Validation accuracy: 0.545.. LR : [1.838265624999999e-05]
# Epoch 40/100.. Train loss: 0.066.. Validation loss: 1.185.. Validation accuracy: 0.591.. LR : [1.838265624999999e-05]
# Epoch 42/100.. Train loss: 0.054.. Validation loss: 1.148.. Validation accuracy: 0.545.. LR : [1.838265624999999e-05]
# Epoch 44/100.. Train loss: 0.028.. Validation loss: 1.164.. Validation accuracy: 0.545.. LR : [6.433929687499997e-06]
# Epoch 45/100.. Train loss: 0.069.. Validation loss: 1.158.. Validation accuracy: 0.500.. LR : [6.433929687499997e-06]
# Epoch 47/100.. Train loss: 0.066.. Validation loss: 1.210.. Validation accuracy: 0.545.. LR : [6.433929687499997e-06]
# Epoch 49/100.. Train loss: 0.035.. Validation loss: 1.189.. Validation accuracy: 0.545.. LR : [7.881563867187495e-07]
# Epoch 50/100.. Train loss: 0.095.. Validation loss: 1.191.. Validation accuracy: 0.500.. LR : [2.251875390624999e-06]
# Epoch 52/100.. Train loss: 0.039.. Validation loss: 1.217.. Validation accuracy: 0.545.. LR : [2.251875390624999e-06]
# Epoch 54/100.. Train loss: 0.024.. Validation loss: 1.188.. Validation accuracy: 0.591.. LR : [2.251875390624999e-06]
# Epoch 55/100.. Train loss: 0.048.. Validation loss: 1.225.. Validation accuracy: 0.545.. LR : [2.758547353515623e-07]
# Epoch 57/100.. Train loss: 0.062.. Validation loss: 1.203.. Validation accuracy: 0.545.. LR : [7.881563867187495e-07]
# Epoch 59/100.. Train loss: 0.030.. Validation loss: 1.232.. Validation accuracy: 0.545.. LR : [7.881563867187495e-07]
# Epoch 60/100.. Train loss: 0.061.. Validation loss: 1.202.. Validation accuracy: 0.591.. LR : [7.881563867187495e-07]
# Epoch 62/100.. Train loss: 0.044.. Validation loss: 1.209.. Validation accuracy: 0.545.. LR : [2.758547353515623e-07]
# Epoch 64/100.. Train loss: 0.046.. Validation loss: 1.252.. Validation accuracy: 0.500.. LR : [2.758547353515623e-07]
# Epoch 65/100.. Train loss: 0.063.. Validation loss: 1.234.. Validation accuracy: 0.500.. LR : [2.758547353515623e-07]
# Epoch 67/100.. Train loss: 0.061.. Validation loss: 1.212.. Validation accuracy: 0.500.. LR : [3.379220508056638e-08]
# Epoch 69/100.. Train loss: 0.018.. Validation loss: 1.209.. Validation accuracy: 0.500.. LR : [9.65491573730468e-08]
# Epoch 70/100.. Train loss: 0.075.. Validation loss: 1.227.. Validation accuracy: 0.500.. LR : [9.65491573730468e-08]
# Epoch 72/100.. Train loss: 0.056.. Validation loss: 1.273.. Validation accuracy: 0.500.. LR : [9.65491573730468e-08]
# Epoch 74/100.. Train loss: 0.024.. Validation loss: 1.250.. Validation accuracy: 0.500.. LR : [3.379220508056638e-08]
# Epoch 75/100.. Train loss: 0.094.. Validation loss: 1.242.. Validation accuracy: 0.500.. LR : [3.379220508056638e-08]
# Epoch 77/100.. Train loss: 0.067.. Validation loss: 1.220.. Validation accuracy: 0.455.. LR : [3.379220508056638e-08]
# Epoch 79/100.. Train loss: 0.026.. Validation loss: 1.228.. Validation accuracy: 0.545.. LR : [4.139545122369381e-09]
# Epoch 80/100.. Train loss: 0.092.. Validation loss: 1.230.. Validation accuracy: 0.545.. LR : [1.1827271778198232e-08]
# Epoch 82/100.. Train loss: 0.054.. Validation loss: 1.226.. Validation accuracy: 0.500.. LR : [1.1827271778198232e-08]
# Epoch 84/100.. Train loss: 0.026.. Validation loss: 1.215.. Validation accuracy: 0.545.. LR : [1.1827271778198232e-08]
# Epoch 85/100.. Train loss: 0.085.. Validation loss: 1.225.. Validation accuracy: 0.591.. LR : [1.4488407928292831e-09]
# Epoch 87/100.. Train loss: 0.047.. Validation loss: 1.232.. Validation accuracy: 0.545.. LR : [4.139545122369381e-09]
# Epoch 89/100.. Train loss: 0.015.. Validation loss: 1.172.. Validation accuracy: 0.591.. LR : [4.139545122369381e-09]
# Epoch 90/100.. Train loss: 0.098.. Validation loss: 1.171.. Validation accuracy: 0.545.. LR : [4.139545122369381e-09]
# Epoch 92/100.. Train loss: 0.036.. Validation loss: 1.196.. Validation accuracy: 0.545.. LR : [1.4488407928292831e-09]
# Epoch 94/100.. Train loss: 0.017.. Validation loss: 1.210.. Validation accuracy: 0.545.. LR : [1.4488407928292831e-09]
# Epoch 95/100.. Train loss: 0.093.. Validation loss: 1.222.. Validation accuracy: 0.500.. LR : [1.4488407928292831e-09]
# Epoch 97/100.. Train loss: 0.035.. Validation loss: 1.233.. Validation accuracy: 0.500.. LR : [1.7748299712158716e-10]
# Epoch 99/100.. Train loss: 0.015.. Validation loss: 1.260.. Validation accuracy: 0.500.. LR : [5.07094277490249e-10]
# Epoch 100/100.. Train loss: 0.078.. Validation loss: 1.250.. Validation accuracy: 0.455.. LR : [5.07094277490249e-10]

# %% [markdown]
# ### **Analysis of Training and Validation Losses and Accuracy**

# %%
model.load_state_dict(torch.load("/content/gdrive/MyDrive/model.pt"))
# Out:
# <All keys matched successfully>

# %%
plt.plot(train_losses, label='Training loss')
plt.plot(valid_losses, label='Validation loss')
plt.legend(frameon=False)

# %%
plt.plot(valid_acc, label='Validation Accuracy')
plt.legend(frameon=False)

# %% [markdown]
# ## **Model Evaluation**

# %%
model.eval() # Prep model for Evaluation

mean_of = 5 # Mean of how many evaluations
valid_loss = 0.0
class_correct = list(0. for i in range(len(classes))) # List of number of correct predictions in each class
class_total = list(0. for i in range(len(classes))) # List of total number of samples in each class

for i in range(mean_of):
  for data, target in test_loader:
    # Move the data to device
    data, target = data.to(device), target.to(device)
    # forward pass: compute predicted outputs by passing inputs to the model
    output = model(data)
    # calculate the loss
    loss = criterion(output, target)
    # update test loss 
    valid_loss += loss.item()*data.size(0)
    # convert output probabilities to predicted class
    _, pred = torch.max(output, 1)
    # compare predictions to true label
    correct = np.squeeze(pred.eq(target.data.view_as(pred)))
    
    # calculate test accuracy for each object class
    for i in range(len(target)):    
        label = target.data[i]
        if len(target) == 1:
          class_correct[label] += correct.item()
        else:
          class_correct[label] += correct[i].item()
        class_total[label] += 1

# calculate and print average test loss
valid_loss = valid_loss/(mean_of * len(test_loader.dataset))
print('Test Loss: {:.6f}\n'.format(valid_loss))

# print accuracy of each class
for i in range(len(classes)):
    if class_total[i] > 0:
        print('Test Accuracy of %5s: %0.2f%% (%2d/%2d)' % (
            str(i), 100 * class_correct[i] / class_total[i],
            np.sum(class_correct[i]), np.sum(class_total[i])))
    else:
        print('Test Accuracy of %5s: N/A (no training examples)' % (classes[i]))
acc = 100. * np.sum(class_correct) / np.sum(class_total)

# print total accuracy of the model
print('\nTest Accuracy (Overall): %0.2f%% (%2d/%2d)' % (
    acc,
    np.sum(class_correct), np.sum(class_total)))
# Out:
# Test Loss: 0.611023
#
# Test Accuracy of     0: 100.00% (30/30)
# Test Accuracy of     1: 80.00% (20/25)
# Test Accuracy of     2: 50.00% (15/30)
# Test Accuracy of     3: 80.00% (20/25)
#
# Test Accuracy (Overall): 77.27% (85/110)

# %%
## To check on a custom Image

img = Image.open('/content/gdrive/MyDrive/motifbatikpapua3/test/motif cendrawasih/cen07.jpg')
# Convert 2D image to 1D vector
images = test_transforms(img)

plt.imshow(denormalise(images))
# Calculate the class probabilities (softmax) for img
with torch.no_grad():
  images = images.to(device)
  output = model(images.unsqueeze(0))

ps = F.softmax(output, dim =1 )

classes[int(torch.argmax(ps).item())]
# Out:
# 'motif raja ampat'

# %%
# Check which images, the model predicted incorrectly with correct and predicted label and the probability

classes
dataiter = iter(test_loader)
images, labels = dataiter.next()
with torch.no_grad():
  images, labels = images.to(device), labels.to(device)
  output = model(images)

ps = F.softmax(output, dim =1 )

#images = images.cpu().numpy()


fig = plt.figure(figsize=(25,16))
i = 1
for idx in np.arange(22):
  pred = torch.argmax(ps[idx]).item()
  prob = ps[idx][pred]
  if labels[idx].item() != pred:
    ax = fig.add_subplot(8, 64/8, i, xticks=[], yticks=[])
    ax.imshow(denormalise(images[idx]), cmap='gray')
    ax.set_title((str(labels[idx].item())+':'+str(pred))+', '+str(prob.item()))
    i+=1
